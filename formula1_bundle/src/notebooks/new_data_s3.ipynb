# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType, DateType

# %%
source_path = "s3://formula1-project-databricks"

df_sesion24_25  = spark.readStream.format("cloud") \
        .option("cloudFiles.format", "csv") \
        .option("cloudFiles.schemaLocation", "s3://formula1-project-databricks/") \
        .load(source_path)
